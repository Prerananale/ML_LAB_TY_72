# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Specify the full path to the file
file_path = "C:\\Users\\HP\\Downloads\\archive (8)\\diabetes.csv"

# Load the dataset using the updated file path
pima = pd.read_csv(file_path, header=None, names=col_names)

# %%
pima.head()
# Out:
#       pregnant  glucose             bp           skin  insulin   bmi  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                    pedigree  age    label
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming X_test is a DataFrame with non-numeric columns
encoder = LabelEncoder()

# Encode non-numeric columns
for col in X_test.columns:
    if X_test[col].dtype == 'object':
        X_test[col] = encoder.fit_transform(X_test[col])

# Now, you can use X_test for prediction
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5844155844155844

# %%
from six import StringIO

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6493506493506493

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# Example values for demonstration
value1 = 1
value2 = 2
value3 = 3
target_value1 = 0
target_value2 = 1
target_value3 = 0

# Assuming X_train and y_train are your actual training data
X_train = pd.DataFrame({'feature1': [value1, value2, value3], 'feature2': [value1, value2, value3]})
y_train = pd.Series([target_value1, target_value2, target_value3])

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Define feature_cols with the names of your features
feature_cols = ['feature1', 'feature2', 'feature3']

plt.figure(figsize=(20, 10))
plot_tree(clf, filled=True, feature_names=feature_cols, class_names=['0', '1'])
plt.savefig('diabetes.png')  # Save the plot as an image file
plt.show()
